# %% [markdown]
# <a href="https://colab.research.google.com/github/SajalSinha/Car_and_person/blob/main/Final_assignment_EagleView.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# YoloV5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-132-g5bdb28e torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/78.2 GB disk)

# %%
# !unzip /content/drive/MyDrive/Assignment/train_data.zip -d /content/train_data.

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.7 MB 11.3 MB/s
#      |████████████████████████████████| 180 kB 36.1 MB/s
#      |████████████████████████████████| 97 kB 6.0 MB/s
#      |████████████████████████████████| 140 kB 50.3 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 10 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: sajalsinha (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-132-g5bdb28e torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# ##**Weight & Bias Dashboard Link For YOLOV5**
#
# https://wandb.ai/sajalsinha/YOLOv5/runs/31pj9lb8?workspace=user-sajalsinha

# %%
from utils.plots import plot_results 
plot_results('/content/yolov5/runs/train/exp3/results.csv')

# %%
display.Image(filename='/content/yolov5/runs/train/exp3/results.png', width=1000)

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/istockphoto-1125352388-612x612.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/istockphoto-1125352388-612x612.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-5-g9d0e1cf torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/istockphoto-1125352388-612x612.jpg: 448x640 Done. (0.030s)
# Speed: 0.5ms pre-process, 29.8ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %% [markdown]
# YOLOV3

# %%
# !git clone https://github.com/ultralytics/yolov3  # clone
# %cd yolov3
# %pip install -qr requirements.txt  # install

import torch
from yolov3 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv3 🚀 v9.6.0-5-g9d0e1cf torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅

# %%
# Train YOLOv3 on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 10 --data custom_data.yaml --weights yolov3.pt --cache
# Out:
# wandb: Currently logged in as: sajalsinha (use `wandb login --relogin` to force relogin)
# train: weights=yolov3.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov3 ✅
# YOLOv3 🚀 v9.6.0-5-g9d0e1cf torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# ##**Weight & Bias Dashboard Link For YOLOV3**
#
# https://wandb.ai/sajalsinha/YOLOv3/runs/2grnztes?workspace=user-sajalsinha

# %%
from utils.plots import plot_results 
plot_results('/content/yolov3/runs/train/exp5/results.csv')

# %%
display.Image(filename='/content/yolov3/runs/train/exp5/results.png', width=1000)

# %%
# !python detect.py --weights /content/yolov3/runs/train/exp5/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/istockphoto-1125352388-612x612.jpg
# Out:
# detect: weights=['/content/yolov3/runs/train/exp5/weights/best.pt'], source=/content/drive/MyDrive/istockphoto-1125352388-612x612.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-5-g9d0e1cf torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61502815 parameters, 0 gradients, 154.7 GFLOPs
# image 1/1 /content/drive/MyDrive/istockphoto-1125352388-612x612.jpg: 448x640 Done. (0.130s)
# Speed: 0.5ms pre-process, 129.8ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7
